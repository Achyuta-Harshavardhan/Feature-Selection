# %% [markdown]
# <a href="https://colab.research.google.com/github/Achyuta-Harshavardhan/Feature-Selection/blob/main/Feature_Selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dropping Constant Features using Varience Threshold

# %% [markdown]
# **Variance Threshold**
#
# It removes all the low varience features
#
# It is also used for unsupervised learning as it looks only independen featured  (x), not the desired outputs (y)

# %%
# Import all the necessary libraries
import pandas as pd 
from sklearn.feature_selection import VarianceThreshold

# %%
# To readt the data from CSV file
data = pd.read_csv("/content/drive/MyDrive/Machine Learning/Feature Selection/santander.csv")
data.head()
# Out:
#    ID  var3  var15  ...  saldo_medio_var44_ult3          var38  TARGET
# 0   1     2     23  ...                     0.0   39205.170000     0.0
# 1   3     2     34  ...                     0.0   49278.030000     0.0
# 2   4     2     23  ...                     0.0   67333.770000     0.0
# 3   8     2     37  ...                     0.0   64007.970000     0.0
# 4  10     2     39  ...                     0.0  117310.979016     0.0
#
# [5 rows x 371 columns]

# %%
# Independent and dependent features
x = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
# Varience Threshold --> It is used to remove all the column which is having varience 0
varience_threshold = VarianceThreshold()
varience_threshold.fit(x)
# Out:
# VarianceThreshold(threshold=0.0)

# %%
# Shape of the independent features before varience thresholding
x.shape
# Out:
# (17462, 370)

# %%
# Threshold = 0 --> False else True
varience_threshold.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False,  True,  True,  True,  True,  True, False,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False, False, False, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False, False,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True, False, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False, False,  True,  True,  True,
#         True,  True, False, False,  True,  True,  True,  True,  True,
# ...

# %%
# collecting the features which is not having zero varience
x = x[x.columns[varience_threshold.get_support()]]
x.head()
# Out:
#    ID  var3  ...  saldo_medio_var44_ult3          var38
# 0   1     2  ...                     0.0   39205.170000
# 1   3     2  ...                     0.0   49278.030000
# 2   4     2  ...                     0.0   67333.770000
# 3   8     2  ...                     0.0   64007.970000
# 4  10     2  ...                     0.0  117310.979016
#
# [5 rows x 297 columns]

# %%
# Shape of the independent features after varience thresholding
x.shape
# Out:
# (17462, 297)

# %% [markdown]
# # Removing Highly Correlated Features

# %%
# Import all the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split

# %%
# loading dataset
data = load_boston()
df = pd.DataFrame(data.data,columns=data.feature_names)
df['MEDV'] = data.target

# %%
# Display first five features
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
# Independent and Dependent features
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
# train and test split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
# Shape of the independent features before removing highly correlated features
x_train.shape
# Out:
# (354, 13)

# %%
plt.figure(figsize=(12,10))
cor = x_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(x_train, 0.7)
corr_features
# Out:
# {'AGE', 'NOX', 'TAX'}

# %%
x_train = x_train.drop(corr_features,axis=1)
x_test = x_test.drop(corr_features,axis=1)

# %%
# Shape of the independent features after removing highly correlated features
x_train.shape
# Out:
# (354, 10)

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Machine Learning/Feature Selection/santander.csv")

# %%
x = df1.iloc[:,:-1]
y = df1.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train.head()
# Out:
#           ID  var3  ...  saldo_medio_var44_ult3      var38
# 13166  26389     2  ...                     0.0   56028.48
# 9131   18380     2  ...                     0.0  109318.80
# 5745   11527     2  ...                     0.0   57245.22
# 16126  32364     2  ...                     0.0  158548.86
# 12549  25158     2  ...                     0.0   81865.50
#
# [5 rows x 370 columns]

# %%
plt.figure(figsize=(12,10))
cor = x_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
corr_features = correlation(x_train, 0.8)

# %%
x_train = x_train.drop(corr_features,axis=1)
x_test = x_test.drop(corr_features,axis=1)

# %%
x_train.head()
# Out:
#           ID  var3  ...  saldo_medio_var44_hace2      var38
# 13166  26389     2  ...                      0.0   56028.48
# 9131   18380     2  ...                      0.0  109318.80
# 5745   11527     2  ...                      0.0   57245.22
# 16126  32364     2  ...                      0.0  158548.86
# 12549  25158     2  ...                      0.0   81865.50
#
# [5 rows x 181 columns]

# %% [markdown]
# # Univariate Selection

# %%
# Import all the necessary libraries
import pandas as pd
from sklearn.feature_selection import SelectKBest,chi2

# %%
# Read the data from CSV file
df1 = pd.read_csv("/content/drive/MyDrive/Machine Learning/Feature Selection/mobile_dataset.csv")

# %%
# Display first five recoreds
df1.head()
# Out:
#    battery_power  blue  clock_speed  ...  touch_screen  wifi  price_range
# 0            842     0          2.2  ...             0     1            1
# 1           1021     1          0.5  ...             1     0            2
# 2            563     1          0.5  ...             1     0            2
# 3            615     1          2.5  ...             0     0            2
# 4           1821     1          1.2  ...             1     0            1
#
# [5 rows x 21 columns]

# %%
# Independent and dependent features
x = df1.iloc[:,:-1]
y = df1.iloc[:,-1]

# %%
ordered_rank_features = SelectKBest(score_func=chi2,k=20)
ordered_feature = ordered_rank_features.fit(x,y)

# %%
dfscores = pd.DataFrame(ordered_feature.scores_,columns=["Score"])
dfcolumns = pd.DataFrame(x.columns)

# %%
features_rank=pd.concat([dfcolumns,dfscores],axis=1)
features_rank.columns=['Features','Score']
features_rank
# Out:
#          Features          Score
# 0   battery_power   14129.866576
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 4              fc      10.135166
# 5          four_g       1.521572
# 6      int_memory      89.839124
# 7           m_dep       0.745820
# 8       mobile_wt      95.972863
# 9         n_cores       9.097556
# 10             pc       9.186054
# 11      px_height   17363.569536
# 12       px_width    9810.586750
# 13            ram  931267.519053
# 14           sc_h       9.614878
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 17        three_g       0.327643
# 18   touch_screen       1.928429
# 19           wifi       0.422091

# %%
features_rank.nlargest(10,'Score')
# Out:
#          Features          Score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878

# %% [markdown]
# # Feature Importance
# This technique gives you a score for each feature of your data,the higher the score more relevant it is

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model=ExtraTreesClassifier()
model.fit(x,y)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
print(model.feature_importances_)
# Out:
# [0.0616848  0.02102524 0.0335425  0.0192746  0.03204176 0.01766712
#  0.03509124 0.0342751  0.03580178 0.03365899 0.0346418  0.04647181
#  0.04921726 0.38889764 0.03382355 0.03488998 0.03454188 0.01434477
#  0.01971965 0.01938855]

# %%
ranked_features=pd.Series(model.feature_importances_,index=x.columns)
ranked_features.nlargest(20).plot(kind='barh')
plt.show()

# %% [markdown]
# # Information Gain

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
mutual_info = mutual_info_classif(x,y)
mutual_data = pd.Series(mutual_info,index=x.columns)
mutual_data.sort_values(ascending=False)
# Out:
# ram              0.844467
# m_dep            0.037283
# px_width         0.034524
# px_height        0.028191
# battery_power    0.025841
# pc               0.025255
# four_g           0.019982
# sc_h             0.015912
# touch_screen     0.015447
# wifi             0.013452
# dual_sim         0.003569
# sc_w             0.000000
# mobile_wt        0.000000
# talk_time        0.000000
# int_memory       0.000000
# three_g          0.000000
# fc               0.000000
# clock_speed      0.000000
# blue             0.000000
# n_cores          0.000000
# dtype: float64
